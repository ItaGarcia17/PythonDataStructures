# %% [markdown]
# <a href="https://colab.research.google.com/github/ItaGarcia17/PythonDataStructures/blob/main/PythonDataStructures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step(1): Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Step(2): Loading iris dataset
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Step(3): Dropping the "species" column
iris = iris.drop(labels = 'species', axis = 1)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
# Step(4) Adding columns:
iris['sepal_sum'] = iris['sepal_length'] + iris['sepal_width']
iris.head()
iris['petal_sum'] = iris['petal_length'] + iris['petal_width']
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  sepal_sum  petal_sum
# 0           5.1          3.5           1.4          0.2        8.6        1.6
# 1           4.9          3.0           1.4          0.2        7.9        1.6
# 2           4.7          3.2           1.3          0.2        7.9        1.5
# 3           4.6          3.1           1.5          0.2        7.7        1.7
# 4           5.0          3.6           1.4          0.2        8.6        1.6

# %%
# Step(5) :
mean = [np.mean(iris['sepal_length']),
        np.mean(iris['sepal_width']),
        np.mean(iris['sepal_sum']),
        np.mean(iris['petal_length']),
        np.mean(iris['petal_width'])]

mean = list(iris.mean())

summary_dict = {'mean':mean}

summary_df = pd.DataFrame(data = summary_dict)

summary_df
# Out:
#        mean
# 0  5.843333
# 1  3.057333
# 2  3.758000
# 3  1.199333
# 4  8.900667
# 5  4.957333

# %%
iris.std()
# Out:
# sepal_length    0.828066
# sepal_width     0.435866
# petal_length    1.765298
# petal_width     0.762238
# sepal_sum       0.889272
# petal_sum       2.507689
# dtype: float64

# %%
iris.min()
# Out:
# sepal_length    4.3
# sepal_width     2.0
# petal_length    1.0
# petal_width     0.1
# sepal_sum       6.8
# petal_sum       1.2
# dtype: float64

# %%
iris.max()
# Out:
# sepal_length     7.9
# sepal_width      4.4
# petal_length     6.9
# petal_width      2.5
# sepal_sum       11.7
# petal_sum        9.2
# dtype: float64

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width   sepal_sum  \
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.057333      3.758000     1.199333    8.900667
# std        0.828066     0.435866      1.765298     0.762238    0.889272
# min        4.300000     2.000000      1.000000     0.100000    6.800000
# 25%        5.100000     2.800000      1.600000     0.300000    8.300000
# 50%        5.800000     3.000000      4.350000     1.300000    8.850000
# 75%        6.400000     3.300000      5.100000     1.800000    9.575000
# max        7.900000     4.400000      6.900000     2.500000   11.700000
#
#         petal_sum
# count  150.000000
# mean     4.957333
# std      2.507689
# min      1.200000
# 25%      1.800000
# 50%      5.650000
# 75%      7.000000
# max      9.200000
